# %% [markdown]
# <a href="https://colab.research.google.com/github/pk142/DSML/blob/main/Spotify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Data.xlsx")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    int64
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    float64
#  14  bpm                   953 non-null    int64
# ...

# %%
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
df_copy = df

# %%
df_Artist = df[['track_name','artist(s)_name']]
df_Artist = df_Artist.assign(artist=df_Artist['artist(s)_name'].str.split(', '))

# %%
df_Artist.head()
# Out:
#                             track_name    artist(s)_name              artist
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook  [Latto, Jung Kook]
# 1                                 LALA       Myke Towers       [Myke Towers]
# 2                              vampire    Olivia Rodrigo    [Olivia Rodrigo]
# 3                         Cruel Summer      Taylor Swift      [Taylor Swift]
# 4                       WHERE SHE GOES         Bad Bunny         [Bad Bunny]

# %%
df_Artist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   track_name      953 non-null    object
#  1   artist(s)_name  953 non-null    object
#  2   artist          953 non-null    object
# dtypes: object(3)
# memory usage: 22.5+ KB

# %%
df_Artist=df_Artist.explode('artist')

# %%
df_Artist.head()
# Out:
#                             track_name    artist(s)_name          artist
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook           Latto
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook       Jung Kook
# 1                                 LALA       Myke Towers     Myke Towers
# 2                              vampire    Olivia Rodrigo  Olivia Rodrigo
# 3                         Cruel Summer      Taylor Swift    Taylor Swift

# %%
df_Artist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1482 entries, 0 to 952
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   track_name      1482 non-null   object
#  1   artist(s)_name  1482 non-null   object
#  2   artist          1482 non-null   object
# dtypes: object(3)
# memory usage: 46.3+ KB

# %%
df_copy = pd.merge(df_Artist,df_copy, on='track_name', how='left')
# Out:
# <ipython-input-36-e4b0bba8c8a3>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'artist(s)_name_y'} in the result is deprecated and will raise a MergeError in a future version.
#   df_copy = pd.merge(df_Artist,df_copy, on='track_name', how='left')

# %%
df_copy.head()
# Out:
#                             track_name  artist(s)_name_x          artist  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook           Latto
# 1  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook       Jung Kook
# 2                                 LALA       Myke Towers     Myke Towers
# 3                              vampire    Olivia Rodrigo  Olivia Rodrigo
# 4                         Cruel Summer      Taylor Swift    Taylor Swift
#
#    artist(s)_name_x  artist_count  released_year  released_month  \
# 0  Latto, Jung Kook             2           2023               7
# 1  Latto, Jung Kook             2           2023               7
# 2       Myke Towers             1           2023               3
# 3    Olivia Rodrigo             1           2023               6
# 4      Taylor Swift             1           2019               8
#
#    released_day  in_spotify_playlists  in_spotify_charts  ... valence_%  \
# ...
